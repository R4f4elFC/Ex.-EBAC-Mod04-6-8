# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ##  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %% [markdown]
# - http://apidatalake.tesouro.gov.br/docs/sadipem/#/PVL%20-%20Dados%20B%C3%A1sicos

# %%
# 1) Seu código aqui
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Estado'
dados_rj = requests.get(url)  
dados_rj.status_code
data_rj_json = dados_rj.json()
#print(data_rj_json['items'])
df_rj = pd.DataFrame(data_rj_json['items'])
df_rj.head(2)
# Out:
#    id_pleito tipo_interessado     interessado  cod_ibge  uf num_pvl  \
# 0       7187           Estado  Rio de Janeiro        33  RJ    None
# 1       9042           Estado  Rio de Janeiro        33  RJ    None
#
#                                               status          num_processo  \
# 0  Encaminhado à PGFN com manifestação técnica fa...  17944.000517/2012-93
# 1                                 Arquivado a pedido  17944.000891/2013-70
#
#          data_protocolo                                      tipo_operacao  \
# 0  2012-04-16T03:00:00Z  Operação contratual externa (com garantia da U...
# 1  2013-09-20T03:00:00Z  Operação contratual interna (com garantia da U...
#
#        finalidade                           tipo_credor  \
# 0  Infraestrutura  Instituição Financeira Internacional
# 1  Infraestrutura       Instituição Financeira Nacional
#
#                                 credor          moeda        valor  \
# 0  Agência Francesa de Desenvolvimento  Dólar dos EUA  394500000.0
# 1                  Banco Itaú BBA S.A.           Real  400000000.0
#
#    pvl_assoc_divida  pvl_contradado_credor data_status
# 0                 1                      0  28/08/2012
# 1                 0                      0  05/02/2014

# %%
# 2) Seu código aqui
df_rj['status'].value_counts()
# Out:
# Encaminhado à PGFN com manifestação técnica favorável    34
# Deferido                                                 14
# Arquivado a pedido                                        3
# Arquivado por decurso de prazo                            1
# Name: status, dtype: int64

# %%
# 3) Seu código aqui
ano_data_status = df_rj['data_status']
ano_status = ano_data_status.str.slice(start=6, stop=10, step=1)
#ano_status

# %%
# 4) Seu código aqui
ano_status.value_counts()
# Out:
# 2012    11
# 2009     9
# 2013     7
# 2011     6
# 2014     4
# 2002     4
# 2016     4
# 2010     3
# 2008     2
# 2006     2
# Name: data_status, dtype: int64

# %% [markdown]
# ##  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?tipo_interessado=Estado'
dados_uf = requests.get(url)  
#dados_uf.status_code
data_uf_json = dados_uf.json()

df_uf = pd.DataFrame(data_uf_json['items'])
df_uf.head(2)
# Out:
#    id_pleito tipo_interessado interessado  cod_ibge  uf               num_pvl  \
# 0      43690           Estado       Ceará        23  CE  PVL02.001902/2020-03
# 1      37592           Estado     Alagoas        27  AL  PVL02.003642/2019-69
#
#                                               status          num_processo  \
# 0  Encaminhado à PGFN com manifestação técnica fa...  17944.100018/2021-96
# 1  Encaminhado à PGFN com manifestação técnica fa...  17944.103439/2019-54
#
#          data_protocolo                                      tipo_operacao  \
# 0  2021-07-21T13:24:41Z  Operação contratual externa (com garantia da U...
# 1  2019-12-10T23:25:12Z  Operação contratual externa (com garantia da U...
#
#                      finalidade                           tipo_credor  \
# 0  Fortalecimento Institucional  Instituição Financeira Internacional
# 1                Multissetorial  Instituição Financeira Internacional
#
#                                     credor          moeda        valor  \
# 0  Banco Interamericano de Desenvolvimento  Dólar dos EUA   28000000.0
# 1             Corporação Andina de Fomento  Dólar dos EUA  136230000.0
#
#    pvl_assoc_divida  pvl_contradado_credor data_status
# 0                 0                      0  24/09/2021
# 1                 1                      0  27/12/2019

# %%
print('Digite o estado (UF) desejado')
filtro_df_uf = df_uf.loc[df_uf['uf'] == input().upper()]
filtro_df_uf.head()
# Out:
# Digite o estado (UF) desejado
# sp
#     id_pleito tipo_interessado interessado  cod_ibge  uf  \
# 2       11505           Estado   São Paulo        35  SP
# 13      28058           Estado   São Paulo        35  SP
# 21      51532           Estado   São Paulo        35  SP
# 31       6413           Estado   São Paulo        35  SP
# 32       6513           Estado   São Paulo        35  SP
#
#                  num_pvl                                             status  \
# 2                   None  Encaminhado à PGFN com manifestação técnica fa...
# 13  PVL02.000587/2018-74  Encaminhado à PGFN com manifestação técnica fa...
# 21  PVL02.006462/2021-53  Encaminhado à PGFN com manifestação técnica fa...
# 31                  None  Encaminhado à PGFN com manifestação técnica fa...
# 32                  None  Encaminhado à PGFN com manifestação técnica fa...
#
#             num_processo        data_protocolo  \
# 2   17944.001464/2008-41  2008-09-10T03:00:00Z
# 13  17944.102744/2018-48  2018-04-25T12:36:06Z
# 21  17944.104649/2021-84  2022-05-20T14:15:40Z
# 31  17944.000340/2003-34  2003-07-03T03:00:00Z
# 32  17944.000370/2013-12  2013-07-04T03:00:00Z
#
#                                         tipo_operacao      finalidade  \
# 2   Operação contratual externa (com garantia da U...  Infraestrutura
# 13  Operação contratual interna (com garantia da U...  Infraestrutura
# 21  Operação contratual interna (com garantia da U...  Infraestrutura
# 31  Operação contratual externa (com garantia da U...  Multissetorial
# 32  Operação contratual interna (com garantia da U...  Multissetorial
#
#                              tipo_credor  \
# 2   Instituição Financeira Internacional
# 13       Instituição Financeira Nacional
# 21       Instituição Financeira Nacional
# 31  Instituição Financeira Internacional
# 32       Instituição Financeira Nacional
#
#                                                credor          moeda  \
# 2             Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 13                      Banco Santander (Brasil) S.A.           Real
# 21  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 31            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 32                                Banco do Brasil S/A           Real
#
#            valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 2   1.940000e+08                 1                      0  19/09/2008
# 13  2.500000e+08                 1                      1  04/05/2018
# 21  1.500000e+09                 0                      0  25/05/2022
# 31  7.066400e+07                 1                      0  06/05/2004
# 32  2.000000e+09                 1                      0  13/08/2013

# %%
# 2) Seu código aqui
df_mg = df_uf.loc[df_uf['uf'] == 'MG']
df_mg['status'].value_counts()
# Out:
# Encaminhado à PGFN com manifestação técnica favorável    20
# Deferido                                                  7
# Arquivado a pedido                                        5
# Arquivado pela STN                                        3
# Arquivado                                                 3
# Indeferido                                                1
# Arquivado por decurso de prazo                            1
# Name: status, dtype: int64

# %%
# 3) Seu código aqui
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=BA&tipo_interessado=Munic%C3%ADpio'
mun_ba = requests.get(url)  
data_uf_json = mun_ba.json()

df_ba_mun = pd.DataFrame(data_uf_json['items'])
df_ba_mun.head(2)
# Out:
#    id_pleito tipo_interessado      interessado  cod_ibge  uf  \
# 0      42393        Município  Rafael Jambeiro   2925956  BA
# 1      30888        Município            Barra   2902708  BA
#
#                 num_pvl             status          num_processo  \
# 0  PVL02.000961/2020-56           Deferido  17944.101782/2020-06
# 1  PVL02.000200/2019-61  Deferido (PVL-IF)                  None
#
#          data_protocolo                tipo_operacao      finalidade  \
# 0  2020-04-06T14:57:42Z  Operação contratual interna  Infraestrutura
# 1                  None  Operação contratual interna  Infraestrutura
#
#                        tipo_credor                                     credor  \
# 0  Instituição Financeira Nacional  Agência de Fomento do Estado da Bahia S/A
# 1  Instituição Financeira Nacional                    Caixa Econômica Federal
#
#   moeda      valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0  Real  3000000.0                 0                      0  13/04/2020
# 1  Real  5000000.0                 0                      1  07/03/2019

# %%
df_ba_def = df_ba_mun.loc[df_ba_mun['status'] == 'Deferido']
df_ba_def['interessado'].value_counts()

# %%
# 4) Seu código aqui
df_ba_def.to_csv('dados_estado_Bahia')
